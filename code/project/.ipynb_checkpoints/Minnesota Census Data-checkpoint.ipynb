# %%
# https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?src=bkmk
# https://mn.gov/admin/demography/data-by-topic/age-race-ethnicity/

# http://www.trbimg.com/img-5928b3b9/turbine/la-me-g-irvine-immigrants-web-demographics/
# https://static01.nyt.com/newsgraphics/2016/09/13/18mag-latino-vote/5f0ea2e1d1f14b3acaf835afe1d0c4f0a1edb04f/latinovote1.png

import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

df = pd.read_csv('acs2006_10yr.csv')

# pd.set_option('display.max_columns', 100)
df.head()
# Out:
#    Year  Total population    White  Black or African American  \
# 0  2000           4933692  4353427                     176223
# 1  2002           5018935  4372702                     196165
# 2  2004           5087713  4379761                     215459
# 3  2006           5163555  4389370                     235886
# 4  2008           5247018  4404774                     257365
#
#    American Indian and Alaska Native   Asian  \
# 0                              52531  146237
# 1                              53269  167083
# 2                              53869   73637
# 3                              54377  188124
# 4                              55198  203070
#
#    Native Hawaiian and Other Pacific Islander  Two or more races  \
# 0                                        1790              58183
# 1                                        1884              68880
# 2                                         910               2783
# 3                                        1956              80918
# 4                                        2024              90558
#
#    Hispanic (of any other races or races)
# 0                                  145301
# 1                                  179719
# 2                                  190294
# 3                                  212924
# 4                                  234029

# %%
# df=df.rename(columns = {'B03002001':'Total population'})

# %%
df.set_index('Year', inplace=True)

# %%
df.head(10)
# Out:
#       Total population    White  Black or African American  \
# Year
# 2000           4933692  4353427                     176223
# 2002           5018935  4372702                     196165
# 2004           5087713  4379761                     215459
# 2006           5163555  4389370                     235886
# 2008           5247018  4404774                     257365
# 2010           5310903  4411802                     272570
# 2012           5380443  4425835                     290042
# 2014           5457125  4442291                     309108
# 2015           5489594  4446535                     317130
#
#       American Indian and Alaska Native   Asian  \
# Year
# 2000                              52531  146237
# 2002                              53269  167083
# 2004                              53869   73637
# 2006                              54377  188124
# 2008                              55198  203070
# 2010                              55755  217008
# 2012                              56914  235057
# 2014                              58119  254951
# 2015                              58603  264609
#
#       Native Hawaiian and Other Pacific Islander  Two or more races  \
# Year
# 2000                                        1790              58183
# 2002                                        1884              68880
# 2004                                         910               2783
# 2006                                        1956              80918
# 2008                                        2024              90558
# 2010                                        2001              99950
# 2012                                        2147             106083
# 2014                                        2341             112596
# 2015                                        2433             116070
#
#       Hispanic (of any other races or races)
# Year
# 2000                                  145301
# 2002                                  179719
# 2004                                  190294
# 2006                                  212924
# 2008                                  234029
# 2010                                  251817
# 2012                                  264365
# 2014                                  277719
# 2015                                  284214

# %%
df.plot(kind='line', figsize=(10,5))

# %%
ax = df.iloc[8].sort_values().plot(figsize=(10,5), kind='barh', color='grey', x='Year')
ax = df.iloc[8].sort_values().plot(figsize=(10,5), kind='barh', color='black', x='Year')
ax = df.iloc[7].sort_values().plot(figsize=(10,5), kind='barh', color='white', x='Year')
ax = df.iloc[6].sort_values().plot(figsize=(10,5), kind='barh', color='purple', x='Year')
ax = df.iloc[5].sort_values().plot(figsize=(10,5), kind='barh', color='orange', x='Year')
ax = df.iloc[4].sort_values().plot(figsize=(10,5), kind='barh', color='green', x='Year')
ax = df.iloc[3].sort_values().plot(figsize=(10,5), kind='barh', color='brown', x='Year')
ax = df.iloc[2].sort_values().plot(figsize=(10,5), kind='barh', color='yellow', x='Year')
ax = df.iloc[1].sort_values().plot(figsize=(10,5), kind='barh', color='blue', x='Year')
ax = df.iloc[0].sort_values().plot(figsize=(10,5), kind='barh', color='red', x='Year')
ax.set_title("Minnesota's population from 2006 to 2015")
ax.set_frame_on(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

# %%
df = pd.read_excel('MN_MidyearPopEstimatesByRE_CensusBureau_2000-2015_tcm36-249143.xls')
df.head(6)
# Out:
#           Population by Race/Ethnicity       2000       2001       2002  \
# 0          Total Population, Minnesota  4933692.0  4982796.0  5018935.0
# 1                             White NH  4353427.0  4367992.0  4372702.0
# 2            Black/African American NH   176223.0   186701.0   196165.0
# 3     American Indian/Alaska Native NH    52531.0    52954.0    53269.0
# 4                             Asian NH   146237.0   153590.0   160668.0
# 5  Native Hawaiian/Pacific Islander NH     1790.0     1839.0     1891.0
#
#         2003       2004       2005       2006       2007       2008  \
# 0  5053572.0  5087713.0  5119598.0  5163555.0  5207203.0  5247018.0
# 1  4376557.0  4379761.0  4380719.0  4389370.0  4398298.0  4404774.0
# 2   205839.0   215459.0   224384.0   235886.0   247253.0   257365.0
# 3    53610.0    53869.0    54057.0    54377.0    54761.0    55198.0
# 4   167083.0   173637.0   180398.0   188124.0   195700.0   203070.0
# 5     1884.0     1910.0     1943.0     1956.0     2026.0     2024.0
#
#         2009       2010       2011       2012       2013       2014       2015
# 0  5281203.0  5310903.0  5348119.0  5380443.0  5420541.0  5457125.0  5489594.0
# 1  4409616.0  4411802.0  4420628.0  4425835.0  4435277.0  4442291.0  4446535.0
# 2   265891.0   272570.0   281535.0   290042.0   299641.0   309108.0   317130.0
# 3    55345.0    55755.0    56416.0    56914.0    57654.0    58119.0    58603.0
# 4   209933.0   217008.0   225988.0   235057.0   245073.0   254951.0   264609.0
# 5     2078.0     2001.0     2098.0     2147.0     2246.0     2341.0     2433.0
